# %%
from IPython.display import clear_output

# Install pymilvus compatible with Milvus v2.3.x
# !python3 -m pip install pymilvus==2.3.7

# Install pymilvus compatible with Milvus v2.4.x
# !python3 -m pip install pymilvus==2.4.4

# Update PyMilvus to the newest version
# !python3 -m pip install --upgrade pymilvus

# Verify installation success
# !python3 -m pip list | grep pymilvus

# !python3 -m pip uninstall -y setuptools

# Required for pymilvus
# !python3 -m pip install setuptools==69.0.3
# Out:
# Collecting pymilvus==2.3.7
#   Using cached pymilvus-2.3.7-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: setuptools>=67 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (69.0.3)
# Requirement already satisfied: grpcio<=1.60.0,>=1.49.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (4.25.5)
# Requirement already satisfied: environs<=9.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (2.2.2)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (2.32.3)
# Requirement already satisfied: minio>=7.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (7.2.12)
# Requirement already satisfied: pyarrow>=12.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (15.0.2)
# Requirement already satisfied: azure-storage-blob in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.3.7) (12.24.0)
# Requirement already satisfied: marshmallow>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus==2.3.7) (3.23.1)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus==2.3.7) (1.0.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus==2.3.7) (2024.8.30)
# Requirement already satisfied: urllib3 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus==2.3.7) (1.26.10)
# Requirement already satisfied: argon2-cffi in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus==2.3.7) (21.3.0)
# Requirement already satisfied: pycryptodome in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus==2.3.7) (3.21.0)
# Requirement already satisfied: typing-extensions in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from minio>=7.0.0->pymilvus==2.3.7) (4.12.2)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.3.7) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2024.1)
# Requirement already satisfied: azure-core>=1.30.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from azure-storage-blob->pymilvus==2.3.7) (1.32.0)
# Requirement already satisfied: cryptography>=2.1.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from azure-storage-blob->pymilvus==2.3.7) (43.0.1)
# Requirement already satisfied: isodate>=0.6.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from azure-storage-blob->pymilvus==2.3.7) (0.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->pymilvus==2.3.7) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from requests->pymilvus==2.3.7) (3.3)
# Requirement already satisfied: six>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from azure-core>=1.30.0->azure-storage-blob->pymilvus==2.3.7) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cryptography>=2.1.4->azure-storage-blob->pymilvus==2.3.7) (1.15.1)
# Requirement already satisfied: packaging>=17.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.3.7) (24.1)
# Requirement already satisfied: argon2-cffi-bindings in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from argon2-cffi->minio>=7.0.0->pymilvus==2.3.7) (21.2.0)
# Requirement already satisfied: pycparser in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->pymilvus==2.3.7) (2.21)
# Using cached pymilvus-2.3.7-py3-none-any.whl (179 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.5.0
#     Uninstalling pymilvus-2.5.0:
#       Successfully uninstalled pymilvus-2.5.0
# Successfully installed pymilvus-2.3.7
# Collecting pymilvus==2.4.4
#   Using cached pymilvus-2.4.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools>=67 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (69.0.3)
# Requirement already satisfied: grpcio<=1.63.0,>=1.49.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (4.25.5)
# Requirement already satisfied: environs<=9.5.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (2.2.2)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus==2.4.4) (2.4.10)
# Requirement already satisfied: marshmallow>=3.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus==2.4.4) (3.23.1)
# Requirement already satisfied: python-dotenv in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from environs<=9.5.0->pymilvus==2.4.4) (1.0.1)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus==2.4.4) (4.66.5)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.4.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2024.1)
# Requirement already satisfied: packaging>=17.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.4.4) (24.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus==2.4.4) (1.16.0)
# Using cached pymilvus-2.4.4-py3-none-any.whl (196 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.3.7
#     Uninstalling pymilvus-2.3.7:
#       Successfully uninstalled pymilvus-2.3.7
# Successfully installed pymilvus-2.4.4
# Requirement already satisfied: pymilvus in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (2.4.4)
# Collecting pymilvus
#   Using cached pymilvus-2.5.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: setuptools>69 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (69.0.3)
# Requirement already satisfied: grpcio<=1.67.1,>=1.49.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (4.25.5)
# Requirement already satisfied: python-dotenv<2.0.0,>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (1.0.1)
# Requirement already satisfied: ujson>=2.0.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite>=2.4.0 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: tqdm in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from milvus-lite>=2.4.0->pymilvus) (4.66.5)
# Requirement already satisfied: numpy>=1.22.4 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from pandas>=1.2.4->pymilvus) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Using cached pymilvus-2.5.0-py3-none-any.whl (212 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.4.4
#     Uninstalling pymilvus-2.4.4:
#       Successfully uninstalled pymilvus-2.4.4
# Successfully installed pymilvus-2.5.0
# pymilvus                         2.5.0
# Found existing installation: setuptools 69.0.3
# Uninstalling setuptools-69.0.3:
#   Successfully uninstalled setuptools-69.0.3
# Collecting setuptools==69.0.3
#   Using cached setuptools-69.0.3-py3-none-any.whl.metadata (6.3 kB)
# Using cached setuptools-69.0.3-py3-none-any.whl (819 kB)
# Installing collected packages: setuptools
# Successfully installed setuptools-69.0.3

# %%
from pprint import pprint

def print_results(results):

    for el in results:
        pprint(el)

# %%
# Open the configuration file
import yaml

with open("credentials.yaml") as f:
    credentials = yaml.safe_load(f)

    CLUSTER_ENDPOINT = credentials["CLUSTER_ENDPOINT"]
    TOKEN = credentials["TOKEN"]

# %%
from pymilvus import MilvusClient

# Initialize a MilvusClient instance
client = MilvusClient(
    uri = CLUSTER_ENDPOINT,
    token = TOKEN
)

# %%
from pymilvus import DataType

# Create a schema
schema = MilvusClient.create_schema(
    auto_id = False,
    enable_dynamic_field = True,
)

# Add the following fields to the schema
# - id (primary, INT64)
# - pet_vector (FLOAT_VECTOR, 5 dimensions)
# - breed_vector (FLOAT_VECTOR, 10 dimensions)
# - species (VARCHAR)
# - eye_color (VARCHAR)
schema.add_field(field_name = "id", datatype = DataType.INT64, is_primary = True)
schema.add_field(field_name = "pet_vector", datatype = DataType.FLOAT_VECTOR, dim = 5)
schema.add_field(field_name = "breed_vector", datatype = DataType.FLOAT_VECTOR, dim = 10)
schema.add_field(field_name = "species", datatype = DataType.VARCHAR, max_length = 1000)
schema.add_field(field_name = "pet_name", datatype = DataType.VARCHAR, max_length = 1000)
# Out:
# {'auto_id': False, 'description': '', 'fields': [{'name': 'id', 'description': '', 'type': <DataType.INT64: 5>, 'is_primary': True, 'auto_id': False}, {'name': 'pet_vector', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 5}}, {'name': 'breed_vector', 'description': '', 'type': <DataType.FLOAT_VECTOR: 101>, 'params': {'dim': 10}}, {'name': 'species', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 1000}}, {'name': 'pet_name', 'description': '', 'type': <DataType.VARCHAR: 21>, 'params': {'max_length': 1000}}], 'enable_dynamic_field': True}

# %%
# Add index to id, pet_vector, breed_vector, and species
index_params = client.prepare_index_params()

index_params.add_index(
    field_name = "id",
    index_type = "STL_SORT"
)

index_params.add_index(
    field_name = "pet_vector",
    index_type = "AUTOINDEX",
    metric_type = "IP",
    params = { "nlist": 128 }
)

index_params.add_index(
    field_name = "breed_vector",
    index_type = "AUTOINDEX",
    metric_type = "IP",
    params = { "nlist": 128 }
)

index_params.add_index(
    field_name = "pet_name",
    index_type = "TRIE"
)

# %%
# Create a collection with the index
client.create_collection(
    collection_name = "pet_collection",
    schema = schema,
    index_params = index_params
)

# Get the collection load state
load_state = client.get_load_state(
    collection_name = "pet_collection"
)

print(load_state)
# Out:
# {'state': <LoadState: Loaded>}

# %%
# Add an alias zoo_collection to the collection
# Create alias
client.create_alias(
    collection_name = "pet_collection",
    alias = "zoo_collection"
)

# %%
# Create two partitions: savannah and artic using the alias zoo_collection
client.create_partition(
    collection_name = "zoo_collection",
    partition_name = "savannah"
)

client.create_partition(
    collection_name = "zoo_collection",
    partition_name = "artic"
)

# Collect the list of partitions
partitions = client.list_partitions(collection_name = "zoo_collection")

print(partitions)
# Out:
# ['_default', 'savannah', 'artic']

# %%
# Create 10k data for the main collection, using proper animal names based on the biome
import random

# List 10 pets to be inserted in the DB
pet_names = ["cat", "dog", "penguin", "lion", "zebra", "cow", "jaguar", "whale", "snake", "spider"]
# List three random species
species = ["feline", "canine", "insect"]

data = []

# Generate 10'000 animals
for i in range(10000):
    data.append({
        "id": i,
        "pet_vector": [ random.uniform(-1, 1) for _ in range(5) ],
        "breed_vector": [ random.uniform(-1, 1) for _ in range(10) ],
        "species": random.choice(species),
        "pet_name": random.choice(pet_names)
    })

# %%
# Add data to the collection and return the number of loaded elements
insert_result = client.insert(
    collection_name = "zoo_collection",
    data = data,
)

print(insert_result["insert_count"])
# Out:
# 10000

# %%
# Create 5k data each for the partitions, using proper animal names based on the biome
import random

# List savannah animals
savannah_pets = ["lion", "zebra", "snake"]
# List artic animals
artic_pets = ["penguin", "whale", "sea lion"]
# List three random species
species = ["feline", "canine", "insect"]

savannah_biome_data = []
artic_biome_data = []

# Generate 10'000 animals
for i in range(10000):
    savannah_biome_data.append({
        "id": i,
        "pet_vector": [ random.uniform(-1, 1) for _ in range(5) ],
        "breed_vector": [ random.uniform(-1, 1) for _ in range(10) ],
        "species": random.choice(species),
        "pet_name": random.choice(savannah_pets)
    })
    
    artic_biome_data.append({
        "id": i,
        "pet_vector": [ random.uniform(-1, 1) for _ in range(5) ],
        "breed_vector": [ random.uniform(-1, 1) for _ in range(10) ],
        "species": random.choice(species),
        "pet_name": random.choice(artic_pets)
    })

# %%
# Upsert the data in both collections and print the number of elements upserted
upsert_partition_status_savannah = client.upsert(
    collection_name = "zoo_collection",
    data = savannah_biome_data,
    partition_name = "savannah"
)

print(upsert_partition_status_savannah["upsert_count"])

upsert_partition_status_artic = client.upsert(
    collection_name = "zoo_collection",
    data = artic_biome_data,
    partition_name = "artic"
)

print(upsert_partition_status_artic["upsert_count"])
# Out:
# 10000
# 10000

# %%
# Delete the first 1k entities in each partition
id_to_delete = [i for i in range(1000)]

delete_status_savannah = client.delete(
    collection_name = "zoo_collection",
    ids = id_to_delete,
    partition_name = "savannah"
)

delete_status_artic = client.delete(
    collection_name = "zoo_collection",
    ids = id_to_delete,
    partition_name = "artic"
)

print(delete_status_savannah)
print(delete_status_artic)
# Out:
# {'delete_count': 1000, 'cost': 1000}
# {'delete_count': 1000, 'cost': 1000}

# %%
# Search for the top 3 elements that are close to a randomly generated breed_vector using IP as the metric
breed_vector = [ random.uniform(-1, 1) for _ in range(10) ]

search_status = client.search(
    collection_name = "zoo_collection",
    data = [breed_vector],
    anns_field = "breed_vector",
    limit = 3,
    search_params = {"metric_type": "IP", "params": {"level": 1}}
)

print_results(search_status)
# Out:
# [{'distance': 3.664642572402954, 'entity': {}, 'id': 3778},
#  {'distance': 3.5751614570617676, 'entity': {}, 'id': 6471},
#  {'distance': 3.4979183673858643, 'entity': {}, 'id': 8509}]

# %%
# Search for the top 5 elements that are close to 3 randomly generated breed_vector using IP as the metric and return their species
breed_vector = [[ random.uniform(-1, 1) for _ in range(10) ] for j in range(3)]

search_status = client.search(
    collection_name = "zoo_collection",
    data = breed_vector,
    anns_field = "breed_vector",
    output_fields = ["species"],
    limit = 5,
    search_params = {"metric_type": "IP", "params": {"level": 1}}
)

print_results(search_status)
# Out:
# [{'distance': 4.191392421722412, 'entity': {'species': 'canine'}, 'id': 2749},
#  {'distance': 4.148306846618652, 'entity': {'species': 'canine'}, 'id': 9191},
#  {'distance': 4.121095657348633, 'entity': {'species': 'feline'}, 'id': 9023},
#  {'distance': 4.038865089416504, 'entity': {'species': 'insect'}, 'id': 5759},
#  {'distance': 3.9527387619018555, 'entity': {'species': 'insect'}, 'id': 5252}]
# [{'distance': 5.270816802978516, 'entity': {'species': 'feline'}, 'id': 7447},
#  {'distance': 4.989281177520752, 'entity': {'species': 'feline'}, 'id': 6582},
#  {'distance': 4.941664695739746, 'entity': {'species': 'canine'}, 'id': 9559},
#  {'distance': 4.854238033294678, 'entity': {'species': 'feline'}, 'id': 3463},
#  {'distance': 4.750955581665039, 'entity': {'species': 'insect'}, 'id': 8557}]
# [{'distance': 4.193144798278809, 'entity': {'species': 'insect'}, 'id': 4864},
#  {'distance': 3.7797577381134033, 'entity': {'species': 'feline'}, 'id': 7522},
#  {'distance': 3.6700568199157715, 'entity': {'species': 'feline'}, 'id': 3763},
#  {'distance': 3.666396141052246, 'entity': {'species': 'canine'}, 'id': 327},
#  {'distance': 3.6552250385284424, 'entity': {'species': 'feline'}, 'id': 3463}]

# %%
# Search the top 10 elements whose pet_name contains the letter i that are close to a randomly generated pet_vector and return their names
pet_vector = [ random.uniform(-1, 1) for _ in range(5) ]

search_status = client.search(
    collection_name = "pet_collection",
    data = [pet_vector],
    anns_field = "pet_vector",
    output_fields = ["pet_name"],
    filter = 'pet_name like "%i%"',
    limit = 10,
    search_params = {"metric_type": "IP", "params": {"level": 1}}
)

print_results(search_status)
# Out:
# [{'distance': 1.0070264339447021,
#   'entity': {'pet_name': 'penguin'},
#   'id': 8900},
#  {'distance': 0.9696456789970398,
#   'entity': {'pet_name': 'sea lion'},
#   'id': 8077},
#  {'distance': 0.922271192073822, 'entity': {'pet_name': 'lion'}, 'id': 5306},
#  {'distance': 0.9179901480674744, 'entity': {'pet_name': 'lion'}, 'id': 2237},
#  {'distance': 0.9049426317214966, 'entity': {'pet_name': 'lion'}, 'id': 8786},
#  {'distance': 0.8988766670227051,
#   'entity': {'pet_name': 'penguin'},
#   'id': 3814},
#  {'distance': 0.8940078020095825,
#   'entity': {'pet_name': 'sea lion'},
#   'id': 5421},
#  {'distance': 0.8882008194923401, 'entity': {'pet_name': 'lion'}, 'id': 2617},
#  {'distance': 0.8848559260368347, 'entity': {'pet_name': 'lion'}, 'id': 5163},
#  {'distance': 0.8777058720588684,
#   'entity': {'pet_name': 'penguin'},
#   'id': 9160}]

# %%
# Perform a group seach for the elements whose pet_name contains the letter i that are close to a randomly generated pet_vector
search_status = client.search(
    collection_name = "pet_collection",
    data = [pet_vector],
    anns_field = "pet_vector",
    output_fields = ["pet_name"],
    filter = 'pet_name like "%i%"',
    group_by_field = "id",
    search_params = {"metric_type": "IP", "params": {"level": 1}}
)

pet_names = [result['entity']['pet_name'] for result in search_status[0]]
print(pet_names)
# Out:
# ['whale', 'sea lion', 'lion', 'lion', 'lion', 'penguin', 'whale', 'lion', 'lion', 'whale']

# %%
# Get the entities with id from 1200 to 1205 for each partition
savannah_elements = client.get(
    collection_name = "zoo_collection",
    ids = [ (i+1200) for i in range(5) ],
    partition = "savannah"
)

print_results(savannah_elements)

artic_elements = client.get(
    collection_name = "zoo_collection",
    ids = [ (i+1200) for i in range(5) ],
    partition = "savannah"
)

print_results(artic_elements)
# Out:
# {'breed_vector': [0.3188581,
#                   0.349546,
#                   -0.28148818,
#                   -0.20696737,
#                   -0.7356126,
#                   0.84210247,
#                   0.0026325332,
#                   -0.22894552,
#                   0.08939071,
#                   -0.16814397],
#  'id': 1200,
#  'pet_name': 'whale',
#  'pet_vector': [0.14852327, -0.43242413, 0.7232335, 0.55974966, -0.27489674],
#  'species': 'insect'}
# {'breed_vector': [0.62408036,
#                   -0.4675496,
#                   0.94817597,
#                   0.52966684,
#                   -0.3527832,
#                   -0.6271419,
#                   0.5591908,
#                   -0.43926305,
#                   -0.39425373,
#                   0.99569786],
#  'id': 1201,
#  'pet_name': 'sea lion',
#  'pet_vector': [0.6612107, -0.12784503, 0.35511193, 0.35368064, 0.91896844],
#  'species': 'canine'}
# {'breed_vector': [0.49948183,
#                   -0.5147771,
#                   -0.83766973,
#                   -0.112088025,
#                   0.95954585,
#                   -0.47455978,
#                   -0.038362835,
#                   -0.7374669,
#                   -0.35254076,
#                   0.09916621],
#  'id': 1202,
#  'pet_name': 'whale',
#  'pet_vector': [-0.49395713,
#                 -0.055756196,
#                 -0.7034944,
#                 -0.83560103,
#                 0.023023376],
#  'species': 'insect'}
# {'breed_vector': [0.19798473,
#                   0.5119968,
#                   0.70127916,
#                   -0.83419335,
#                   -0.9169675,
#                   0.60979456,
#                   0.39414686,
#                   -0.30740857,
#                   -0.9593557,
#                   0.63796234],
#  'id': 1203,
#  'pet_name': 'whale',
#  'pet_vector': [0.87378925, -0.3475308, -0.7196788, -0.76878333, 0.037704814],
#  'species': 'canine'}
# {'breed_vector': [0.35163635,
#                   0.7261493,
#                   -0.57098037,
#                   0.25405607,
#                   -0.058854155,
#                   0.7020501,
#                   -0.15794984,
#                   0.7912016,
#                   -0.24119408,
#                   0.33157754],
#  'id': 1204,
#  'pet_name': 'sea lion',
#  'pet_vector': [-0.99905, 0.7443985, -0.047045086, -0.34206256, -0.9978268],
#  'species': 'feline'}
# {'breed_vector': [0.3188581,
#                   0.349546,
#                   -0.28148818,
#                   -0.20696737,
#                   -0.7356126,
#                   0.84210247,
#                   0.0026325332,
#                   -0.22894552,
#                   0.08939071,
#                   -0.16814397],
#  'id': 1200,
#  'pet_name': 'whale',
#  'pet_vector': [0.14852327, -0.43242413, 0.7232335, 0.55974966, -0.27489674],
#  'species': 'insect'}
# {'breed_vector': [0.62408036,
#                   -0.4675496,
#                   0.94817597,
#                   0.52966684,
#                   -0.3527832,
#                   -0.6271419,
#                   0.5591908,
#                   -0.43926305,
#                   -0.39425373,
#                   0.99569786],
#  'id': 1201,
#  'pet_name': 'sea lion',
#  'pet_vector': [0.6612107, -0.12784503, 0.35511193, 0.35368064, 0.91896844],
#  'species': 'canine'}
# {'breed_vector': [0.49948183,
#                   -0.5147771,
#                   -0.83766973,
#                   -0.112088025,
#                   0.95954585,
#                   -0.47455978,
#                   -0.038362835,
#                   -0.7374669,
#                   -0.35254076,
#                   0.09916621],
#  'id': 1202,
#  'pet_name': 'whale',
#  'pet_vector': [-0.49395713,
#                 -0.055756196,
#                 -0.7034944,
#                 -0.83560103,
#                 0.023023376],
#  'species': 'insect'}
# {'breed_vector': [0.19798473,
#                   0.5119968,
#                   0.70127916,
#                   -0.83419335,
#                   -0.9169675,
#                   0.60979456,
#                   0.39414686,
#                   -0.30740857,
#                   -0.9593557,
#                   0.63796234],
#  'id': 1203,
#  'pet_name': 'whale',
#  'pet_vector': [0.87378925, -0.3475308, -0.7196788, -0.76878333, 0.037704814],
#  'species': 'canine'}
# {'breed_vector': [0.35163635,
#                   0.7261493,
#                   -0.57098037,
#                   0.25405607,
#                   -0.058854155,
#                   0.7020501,
#                   -0.15794984,
#                   0.7912016,
#                   -0.24119408,
#                   0.33157754],
#  'id': 1204,
#  'pet_name': 'sea lion',
#  'pet_vector': [-0.99905, 0.7443985, -0.047045086, -0.34206256, -0.9978268],
#  'species': 'feline'}

# %%
# Perform a query to collect all the elements whose pet_name is spider and return their name
spider_result = client.query(
    collection_name = "pet_collection",
    filter = 'pet_name == "spider"',
    output_fields = ["pet_name"],
)

print_results(spider_result)
# Out:
# {'id': 52, 'pet_name': 'spider'}
# {'id': 59, 'pet_name': 'spider'}
# {'id': 63, 'pet_name': 'spider'}
# {'id': 80, 'pet_name': 'spider'}
# {'id': 114, 'pet_name': 'spider'}
# {'id': 121, 'pet_name': 'spider'}
# {'id': 133, 'pet_name': 'spider'}
# {'id': 142, 'pet_name': 'spider'}
# {'id': 145, 'pet_name': 'spider'}
# {'id': 178, 'pet_name': 'spider'}
# {'id': 193, 'pet_name': 'spider'}
# {'id': 199, 'pet_name': 'spider'}
# {'id': 211, 'pet_name': 'spider'}
# {'id': 212, 'pet_name': 'spider'}
# {'id': 222, 'pet_name': 'spider'}
# {'id': 229, 'pet_name': 'spider'}
# {'id': 255, 'pet_name': 'spider'}
# {'id': 268, 'pet_name': 'spider'}
# {'id': 290, 'pet_name': 'spider'}
# {'id': 292, 'pet_name': 'spider'}
# {'id': 296, 'pet_name': 'spider'}
# {'id': 305, 'pet_name': 'spider'}
# {'id': 328, 'pet_name': 'spider'}
# {'id': 349, 'pet_name': 'spider'}
# {'id': 350, 'pet_name': 'spider'}
# {'id': 379, 'pet_name': 'spider'}
# {'id': 384, 'pet_name': 'spider'}
# {'id': 394, 'pet_name': 'spider'}
# {'id': 397, 'pet_name': 'spider'}
# {'id': 419, 'pet_name': 'spider'}
# {'id': 432, 'pet_name': 'spider'}
# {'id': 434, 'pet_name': 'spider'}
# {'id': 441, 'pet_name': 'spider'}
# {'id': 456, 'pet_name': 'spider'}
# {'id': 463, 'pet_name': 'spider'}
# {'id': 470, 'pet_name': 'spider'}
# {'id': 472, 'pet_name': 'spider'}
# {'id': 493, 'pet_name': 'spider'}
# {'id': 509, 'pet_name': 'spider'}
# {'id': 524, 'pet_name': 'spider'}
# {'id': 544, 'pet_name': 'spider'}
# {'id': 546, 'pet_name': 'spider'}
# {'id': 556, 'pet_name': 'spider'}
# {'id': 563, 'pet_name': 'spider'}
# {'id': 570, 'pet_name': 'spider'}
# {'id': 580, 'pet_name': 'spider'}
# {'id': 583, 'pet_name': 'spider'}
# {'id': 635, 'pet_name': 'spider'}
# {'id': 646, 'pet_name': 'spider'}
# {'id': 650, 'pet_name': 'spider'}
# {'id': 654, 'pet_name': 'spider'}
# {'id': 670, 'pet_name': 'spider'}
# {'id': 678, 'pet_name': 'spider'}
# {'id': 687, 'pet_name': 'spider'}
# {'id': 691, 'pet_name': 'spider'}
# {'id': 708, 'pet_name': 'spider'}
# {'id': 709, 'pet_name': 'spider'}
# {'id': 743, 'pet_name': 'spider'}
# {'id': 752, 'pet_name': 'spider'}
# {'id': 754, 'pet_name': 'spider'}
# {'id': 762, 'pet_name': 'spider'}
# {'id': 786, 'pet_name': 'spider'}
# {'id': 794, 'pet_name': 'spider'}
# {'id': 818, 'pet_name': 'spider'}
# {'id': 824, 'pet_name': 'spider'}
# {'id': 839, 'pet_name': 'spider'}
# {'id': 842, 'pet_name': 'spider'}
# {'id': 851, 'pet_name': 'spider'}
# {'id': 875, 'pet_name': 'spider'}
# {'id': 878, 'pet_name': 'spider'}
# {'id': 899, 'pet_name': 'spider'}
# {'id': 903, 'pet_name': 'spider'}
# {'id': 910, 'pet_name': 'spider'}
# {'id': 932, 'pet_name': 'spider'}
# {'id': 952, 'pet_name': 'spider'}
# {'id': 969, 'pet_name': 'spider'}
# {'id': 972, 'pet_name': 'spider'}
# {'id': 982, 'pet_name': 'spider'}
# {'id': 1006, 'pet_name': 'spider'}
# {'id': 1022, 'pet_name': 'spider'}
# {'id': 1042, 'pet_name': 'spider'}
# {'id': 1043, 'pet_name': 'spider'}
# {'id': 1052, 'pet_name': 'spider'}
# {'id': 1054, 'pet_name': 'spider'}
# {'id': 1058, 'pet_name': 'spider'}
# {'id': 1089, 'pet_name': 'spider'}
# {'id': 1126, 'pet_name': 'spider'}
# {'id': 1129, 'pet_name': 'spider'}
# {'id': 1131, 'pet_name': 'spider'}
# {'id': 1141, 'pet_name': 'spider'}
# {'id': 1145, 'pet_name': 'spider'}
# {'id': 1183, 'pet_name': 'spider'}
# {'id': 1208, 'pet_name': 'spider'}
# {'id': 1220, 'pet_name': 'spider'}
# {'id': 1236, 'pet_name': 'spider'}
# {'id': 1237, 'pet_name': 'spider'}
# {'id': 1242, 'pet_name': 'spider'}
# {'id': 1247, 'pet_name': 'spider'}
# {'id': 1328, 'pet_name': 'spider'}
# {'id': 1332, 'pet_name': 'spider'}
# {'id': 1336, 'pet_name': 'spider'}
# {'id': 1344, 'pet_name': 'spider'}
# {'id': 1346, 'pet_name': 'spider'}
# {'id': 1356, 'pet_name': 'spider'}
# {'id': 1377, 'pet_name': 'spider'}
# {'id': 1383, 'pet_name': 'spider'}
# {'id': 1389, 'pet_name': 'spider'}
# {'id': 1397, 'pet_name': 'spider'}
# {'id': 1411, 'pet_name': 'spider'}
# {'id': 1414, 'pet_name': 'spider'}
# {'id': 1424, 'pet_name': 'spider'}
# {'id': 1427, 'pet_name': 'spider'}
# {'id': 1432, 'pet_name': 'spider'}
# {'id': 1444, 'pet_name': 'spider'}
# {'id': 1456, 'pet_name': 'spider'}
# {'id': 1477, 'pet_name': 'spider'}
# {'id': 1502, 'pet_name': 'spider'}
# {'id': 1512, 'pet_name': 'spider'}
# {'id': 1519, 'pet_name': 'spider'}
# {'id': 1528, 'pet_name': 'spider'}
# {'id': 1542, 'pet_name': 'spider'}
# {'id': 1555, 'pet_name': 'spider'}
# {'id': 1558, 'pet_name': 'spider'}
# {'id': 1560, 'pet_name': 'spider'}
# {'id': 1566, 'pet_name': 'spider'}
# {'id': 1571, 'pet_name': 'spider'}
# {'id': 1573, 'pet_name': 'spider'}
# {'id': 1577, 'pet_name': 'spider'}
# {'id': 1584, 'pet_name': 'spider'}
# {'id': 1606, 'pet_name': 'spider'}
# {'id': 1610, 'pet_name': 'spider'}
# {'id': 1612, 'pet_name': 'spider'}
# {'id': 1614, 'pet_name': 'spider'}
# {'id': 1623, 'pet_name': 'spider'}
# {'id': 1647, 'pet_name': 'spider'}
# {'id': 1667, 'pet_name': 'spider'}
# {'id': 1669, 'pet_name': 'spider'}
# {'id': 1673, 'pet_name': 'spider'}
# {'id': 1704, 'pet_name': 'spider'}
# {'id': 1705, 'pet_name': 'spider'}
# {'id': 1719, 'pet_name': 'spider'}
# {'id': 1746, 'pet_name': 'spider'}
# {'id': 1748, 'pet_name': 'spider'}
# {'id': 1766, 'pet_name': 'spider'}
# {'id': 1779, 'pet_name': 'spider'}
# {'id': 1781, 'pet_name': 'spider'}
# {'id': 1784, 'pet_name': 'spider'}
# {'id': 1789, 'pet_name': 'spider'}
# {'id': 1804, 'pet_name': 'spider'}
# {'id': 1823, 'pet_name': 'spider'}
# {'id': 1839, 'pet_name': 'spider'}
# {'id': 1851, 'pet_name': 'spider'}
# {'id': 1854, 'pet_name': 'spider'}
# {'id': 1857, 'pet_name': 'spider'}
# {'id': 1863, 'pet_name': 'spider'}
# {'id': 1864, 'pet_name': 'spider'}
# {'id': 1880, 'pet_name': 'spider'}
# {'id': 1881, 'pet_name': 'spider'}
# {'id': 1885, 'pet_name': 'spider'}
# {'id': 1917, 'pet_name': 'spider'}
# {'id': 1918, 'pet_name': 'spider'}
# {'id': 1921, 'pet_name': 'spider'}
# {'id': 1924, 'pet_name': 'spider'}
# {'id': 1927, 'pet_name': 'spider'}
# {'id': 1941, 'pet_name': 'spider'}
# {'id': 1949, 'pet_name': 'spider'}
# {'id': 1950, 'pet_name': 'spider'}
# {'id': 1956, 'pet_name': 'spider'}
# {'id': 1974, 'pet_name': 'spider'}
# {'id': 1982, 'pet_name': 'spider'}
# {'id': 1987, 'pet_name': 'spider'}
# {'id': 1990, 'pet_name': 'spider'}
# {'id': 1993, 'pet_name': 'spider'}
# {'id': 1994, 'pet_name': 'spider'}
# {'id': 2008, 'pet_name': 'spider'}
# {'id': 2013, 'pet_name': 'spider'}
# {'id': 2016, 'pet_name': 'spider'}
# {'id': 2024, 'pet_name': 'spider'}
# {'id': 2040, 'pet_name': 'spider'}
# {'id': 2051, 'pet_name': 'spider'}
# {'id': 2056, 'pet_name': 'spider'}
# {'id': 2064, 'pet_name': 'spider'}
# {'id': 2087, 'pet_name': 'spider'}
# {'id': 2099, 'pet_name': 'spider'}
# {'id': 2106, 'pet_name': 'spider'}
# {'id': 2113, 'pet_name': 'spider'}
# {'id': 2119, 'pet_name': 'spider'}
# {'id': 2120, 'pet_name': 'spider'}
# {'id': 2126, 'pet_name': 'spider'}
# {'id': 2140, 'pet_name': 'spider'}
# {'id': 2157, 'pet_name': 'spider'}
# {'id': 2164, 'pet_name': 'spider'}
# {'id': 2173, 'pet_name': 'spider'}
# {'id': 2175, 'pet_name': 'spider'}
# {'id': 2176, 'pet_name': 'spider'}
# {'id': 2179, 'pet_name': 'spider'}
# {'id': 2182, 'pet_name': 'spider'}
# {'id': 2191, 'pet_name': 'spider'}
# {'id': 2197, 'pet_name': 'spider'}
# {'id': 2200, 'pet_name': 'spider'}
# {'id': 2202, 'pet_name': 'spider'}
# {'id': 2204, 'pet_name': 'spider'}
# {'id': 2208, 'pet_name': 'spider'}
# {'id': 2215, 'pet_name': 'spider'}
# {'id': 2218, 'pet_name': 'spider'}
# {'id': 2221, 'pet_name': 'spider'}
# {'id': 2230, 'pet_name': 'spider'}
# {'id': 2265, 'pet_name': 'spider'}
# {'id': 2276, 'pet_name': 'spider'}
# {'id': 2304, 'pet_name': 'spider'}
# {'id': 2312, 'pet_name': 'spider'}
# {'id': 2320, 'pet_name': 'spider'}
# {'id': 2331, 'pet_name': 'spider'}
# {'id': 2335, 'pet_name': 'spider'}
# {'id': 2337, 'pet_name': 'spider'}
# {'id': 2338, 'pet_name': 'spider'}
# {'id': 2352, 'pet_name': 'spider'}
# {'id': 2361, 'pet_name': 'spider'}
# {'id': 2380, 'pet_name': 'spider'}
# {'id': 2388, 'pet_name': 'spider'}
# {'id': 2397, 'pet_name': 'spider'}
# {'id': 2398, 'pet_name': 'spider'}
# {'id': 2400, 'pet_name': 'spider'}
# {'id': 2406, 'pet_name': 'spider'}
# {'id': 2427, 'pet_name': 'spider'}
# {'id': 2431, 'pet_name': 'spider'}
# {'id': 2442, 'pet_name': 'spider'}
# {'id': 2446, 'pet_name': 'spider'}
# {'id': 2455, 'pet_name': 'spider'}
# {'id': 2475, 'pet_name': 'spider'}
# {'id': 2490, 'pet_name': 'spider'}
# {'id': 2492, 'pet_name': 'spider'}
# {'id': 2498, 'pet_name': 'spider'}
# {'id': 2499, 'pet_name': 'spider'}
# {'id': 2504, 'pet_name': 'spider'}
# {'id': 2509, 'pet_name': 'spider'}
# {'id': 2512, 'pet_name': 'spider'}
# {'id': 2516, 'pet_name': 'spider'}
# {'id': 2539, 'pet_name': 'spider'}
# {'id': 2553, 'pet_name': 'spider'}
# {'id': 2560, 'pet_name': 'spider'}
# {'id': 2563, 'pet_name': 'spider'}
# {'id': 2571, 'pet_name': 'spider'}
# {'id': 2584, 'pet_name': 'spider'}
# {'id': 2601, 'pet_name': 'spider'}
# {'id': 2609, 'pet_name': 'spider'}
# {'id': 2616, 'pet_name': 'spider'}
# {'id': 2641, 'pet_name': 'spider'}
# {'id': 2671, 'pet_name': 'spider'}
# {'id': 2681, 'pet_name': 'spider'}
# {'id': 2704, 'pet_name': 'spider'}
# {'id': 2729, 'pet_name': 'spider'}
# {'id': 2735, 'pet_name': 'spider'}
# {'id': 2757, 'pet_name': 'spider'}
# {'id': 2799, 'pet_name': 'spider'}
# {'id': 2807, 'pet_name': 'spider'}
# {'id': 2809, 'pet_name': 'spider'}
# {'id': 2815, 'pet_name': 'spider'}
# {'id': 2830, 'pet_name': 'spider'}
# {'id': 2839, 'pet_name': 'spider'}
# {'id': 2840, 'pet_name': 'spider'}
# {'id': 2858, 'pet_name': 'spider'}
# {'id': 2874, 'pet_name': 'spider'}
# {'id': 2879, 'pet_name': 'spider'}
# {'id': 2886, 'pet_name': 'spider'}
# {'id': 2898, 'pet_name': 'spider'}
# {'id': 2905, 'pet_name': 'spider'}
# {'id': 2910, 'pet_name': 'spider'}
# {'id': 2914, 'pet_name': 'spider'}
# {'id': 2921, 'pet_name': 'spider'}
# {'id': 2932, 'pet_name': 'spider'}
# {'id': 2934, 'pet_name': 'spider'}
# {'id': 2939, 'pet_name': 'spider'}
# {'id': 2940, 'pet_name': 'spider'}
# {'id': 2941, 'pet_name': 'spider'}
# {'id': 2951, 'pet_name': 'spider'}
# {'id': 2953, 'pet_name': 'spider'}
# {'id': 2956, 'pet_name': 'spider'}
# {'id': 2962, 'pet_name': 'spider'}
# {'id': 2984, 'pet_name': 'spider'}
# {'id': 2990, 'pet_name': 'spider'}
# {'id': 3006, 'pet_name': 'spider'}
# {'id': 3030, 'pet_name': 'spider'}
# {'id': 3039, 'pet_name': 'spider'}
# {'id': 3042, 'pet_name': 'spider'}
# {'id': 3048, 'pet_name': 'spider'}
# {'id': 3052, 'pet_name': 'spider'}
# {'id': 3053, 'pet_name': 'spider'}
# {'id': 3063, 'pet_name': 'spider'}
# {'id': 3083, 'pet_name': 'spider'}
# {'id': 3084, 'pet_name': 'spider'}
# {'id': 3087, 'pet_name': 'spider'}
# {'id': 3089, 'pet_name': 'spider'}
# {'id': 3097, 'pet_name': 'spider'}
# {'id': 3103, 'pet_name': 'spider'}
# {'id': 3117, 'pet_name': 'spider'}
# {'id': 3120, 'pet_name': 'spider'}
# {'id': 3144, 'pet_name': 'spider'}
# {'id': 3155, 'pet_name': 'spider'}
# {'id': 3160, 'pet_name': 'spider'}
# {'id': 3177, 'pet_name': 'spider'}
# {'id': 3231, 'pet_name': 'spider'}
# {'id': 3234, 'pet_name': 'spider'}
# {'id': 3235, 'pet_name': 'spider'}
# {'id': 3255, 'pet_name': 'spider'}
# {'id': 3262, 'pet_name': 'spider'}
# {'id': 3266, 'pet_name': 'spider'}
# {'id': 3274, 'pet_name': 'spider'}
# {'id': 3279, 'pet_name': 'spider'}
# {'id': 3297, 'pet_name': 'spider'}
# {'id': 3306, 'pet_name': 'spider'}
# {'id': 3307, 'pet_name': 'spider'}
# {'id': 3342, 'pet_name': 'spider'}
# {'id': 3347, 'pet_name': 'spider'}
# {'id': 3349, 'pet_name': 'spider'}
# {'id': 3356, 'pet_name': 'spider'}
# {'id': 3360, 'pet_name': 'spider'}
# {'id': 3365, 'pet_name': 'spider'}
# {'id': 3366, 'pet_name': 'spider'}
# {'id': 3375, 'pet_name': 'spider'}
# {'id': 3391, 'pet_name': 'spider'}
# {'id': 3395, 'pet_name': 'spider'}
# {'id': 3404, 'pet_name': 'spider'}
# {'id': 3408, 'pet_name': 'spider'}
# {'id': 3409, 'pet_name': 'spider'}
# {'id': 3423, 'pet_name': 'spider'}
# {'id': 3438, 'pet_name': 'spider'}
# {'id': 3443, 'pet_name': 'spider'}
# {'id': 3459, 'pet_name': 'spider'}
# {'id': 3463, 'pet_name': 'spider'}
# {'id': 3464, 'pet_name': 'spider'}
# {'id': 3471, 'pet_name': 'spider'}
# {'id': 3475, 'pet_name': 'spider'}
# {'id': 3489, 'pet_name': 'spider'}
# {'id': 3492, 'pet_name': 'spider'}
# {'id': 3493, 'pet_name': 'spider'}
# {'id': 3498, 'pet_name': 'spider'}
# {'id': 3514, 'pet_name': 'spider'}
# {'id': 3556, 'pet_name': 'spider'}
# {'id': 3560, 'pet_name': 'spider'}
# {'id': 3561, 'pet_name': 'spider'}
# {'id': 3562, 'pet_name': 'spider'}
# {'id': 3564, 'pet_name': 'spider'}
# {'id': 3586, 'pet_name': 'spider'}
# {'id': 3597, 'pet_name': 'spider'}
# {'id': 3611, 'pet_name': 'spider'}
# {'id': 3623, 'pet_name': 'spider'}
# {'id': 3625, 'pet_name': 'spider'}
# {'id': 3631, 'pet_name': 'spider'}
# {'id': 3643, 'pet_name': 'spider'}
# {'id': 3644, 'pet_name': 'spider'}
# {'id': 3652, 'pet_name': 'spider'}
# {'id': 3656, 'pet_name': 'spider'}
# {'id': 3657, 'pet_name': 'spider'}
# {'id': 3697, 'pet_name': 'spider'}
# {'id': 3722, 'pet_name': 'spider'}
# {'id': 3729, 'pet_name': 'spider'}
# {'id': 3730, 'pet_name': 'spider'}
# {'id': 3733, 'pet_name': 'spider'}
# {'id': 3743, 'pet_name': 'spider'}
# {'id': 3783, 'pet_name': 'spider'}
# {'id': 3799, 'pet_name': 'spider'}
# {'id': 3804, 'pet_name': 'spider'}
# {'id': 3805, 'pet_name': 'spider'}
# {'id': 3806, 'pet_name': 'spider'}
# {'id': 3807, 'pet_name': 'spider'}
# {'id': 3808, 'pet_name': 'spider'}
# {'id': 3809, 'pet_name': 'spider'}
# {'id': 3816, 'pet_name': 'spider'}
# {'id': 3819, 'pet_name': 'spider'}
# {'id': 3826, 'pet_name': 'spider'}
# {'id': 3829, 'pet_name': 'spider'}
# {'id': 3830, 'pet_name': 'spider'}
# {'id': 3833, 'pet_name': 'spider'}
# {'id': 3864, 'pet_name': 'spider'}
# {'id': 3875, 'pet_name': 'spider'}
# {'id': 3890, 'pet_name': 'spider'}
# {'id': 3901, 'pet_name': 'spider'}
# {'id': 3922, 'pet_name': 'spider'}
# {'id': 3948, 'pet_name': 'spider'}
# {'id': 3955, 'pet_name': 'spider'}
# {'id': 3959, 'pet_name': 'spider'}
# {'id': 3962, 'pet_name': 'spider'}
# {'id': 3990, 'pet_name': 'spider'}
# {'id': 4013, 'pet_name': 'spider'}
# {'id': 4015, 'pet_name': 'spider'}
# {'id': 4017, 'pet_name': 'spider'}
# {'id': 4035, 'pet_name': 'spider'}
# {'id': 4038, 'pet_name': 'spider'}
# {'id': 4078, 'pet_name': 'spider'}
# {'id': 4080, 'pet_name': 'spider'}
# {'id': 4098, 'pet_name': 'spider'}
# {'id': 4111, 'pet_name': 'spider'}
# {'id': 4127, 'pet_name': 'spider'}
# {'id': 4128, 'pet_name': 'spider'}
# {'id': 4146, 'pet_name': 'spider'}
# {'id': 4165, 'pet_name': 'spider'}
# {'id': 4187, 'pet_name': 'spider'}
# {'id': 4189, 'pet_name': 'spider'}
# {'id': 4194, 'pet_name': 'spider'}
# {'id': 4196, 'pet_name': 'spider'}
# {'id': 4201, 'pet_name': 'spider'}
# {'id': 4202, 'pet_name': 'spider'}
# {'id': 4216, 'pet_name': 'spider'}
# {'id': 4217, 'pet_name': 'spider'}
# {'id': 4225, 'pet_name': 'spider'}
# {'id': 4228, 'pet_name': 'spider'}
# {'id': 4241, 'pet_name': 'spider'}
# {'id': 4253, 'pet_name': 'spider'}
# {'id': 4255, 'pet_name': 'spider'}
# {'id': 4257, 'pet_name': 'spider'}
# {'id': 4263, 'pet_name': 'spider'}
# {'id': 4280, 'pet_name': 'spider'}
# {'id': 4281, 'pet_name': 'spider'}
# {'id': 4283, 'pet_name': 'spider'}
# {'id': 4285, 'pet_name': 'spider'}
# {'id': 4287, 'pet_name': 'spider'}
# {'id': 4290, 'pet_name': 'spider'}
# {'id': 4318, 'pet_name': 'spider'}
# {'id': 4329, 'pet_name': 'spider'}
# {'id': 4334, 'pet_name': 'spider'}
# {'id': 4359, 'pet_name': 'spider'}
# {'id': 4363, 'pet_name': 'spider'}
# {'id': 4365, 'pet_name': 'spider'}
# {'id': 4370, 'pet_name': 'spider'}
# {'id': 4382, 'pet_name': 'spider'}
# {'id': 4395, 'pet_name': 'spider'}
# {'id': 4396, 'pet_name': 'spider'}
# {'id': 4419, 'pet_name': 'spider'}
# {'id': 4425, 'pet_name': 'spider'}
# {'id': 4431, 'pet_name': 'spider'}
# {'id': 4434, 'pet_name': 'spider'}
# {'id': 4435, 'pet_name': 'spider'}
# {'id': 4444, 'pet_name': 'spider'}
# {'id': 4445, 'pet_name': 'spider'}
# {'id': 4459, 'pet_name': 'spider'}
# {'id': 4474, 'pet_name': 'spider'}
# {'id': 4482, 'pet_name': 'spider'}
# {'id': 4521, 'pet_name': 'spider'}
# {'id': 4529, 'pet_name': 'spider'}
# {'id': 4537, 'pet_name': 'spider'}
# {'id': 4546, 'pet_name': 'spider'}
# {'id': 4550, 'pet_name': 'spider'}
# {'id': 4552, 'pet_name': 'spider'}
# {'id': 4553, 'pet_name': 'spider'}
# {'id': 4559, 'pet_name': 'spider'}
# {'id': 4561, 'pet_name': 'spider'}
# {'id': 4567, 'pet_name': 'spider'}
# {'id': 4570, 'pet_name': 'spider'}
# {'id': 4581, 'pet_name': 'spider'}
# {'id': 4599, 'pet_name': 'spider'}
# {'id': 4601, 'pet_name': 'spider'}
# {'id': 4606, 'pet_name': 'spider'}
# {'id': 4611, 'pet_name': 'spider'}
# {'id': 4612, 'pet_name': 'spider'}
# {'id': 4617, 'pet_name': 'spider'}
# {'id': 4629, 'pet_name': 'spider'}
# {'id': 4635, 'pet_name': 'spider'}
# {'id': 4638, 'pet_name': 'spider'}
# {'id': 4644, 'pet_name': 'spider'}
# {'id': 4652, 'pet_name': 'spider'}
# {'id': 4660, 'pet_name': 'spider'}
# {'id': 4662, 'pet_name': 'spider'}
# {'id': 4667, 'pet_name': 'spider'}
# {'id': 4669, 'pet_name': 'spider'}
# {'id': 4670, 'pet_name': 'spider'}
# {'id': 4684, 'pet_name': 'spider'}
# {'id': 4685, 'pet_name': 'spider'}
# {'id': 4709, 'pet_name': 'spider'}
# {'id': 4712, 'pet_name': 'spider'}
# {'id': 4745, 'pet_name': 'spider'}
# {'id': 4750, 'pet_name': 'spider'}
# {'id': 4752, 'pet_name': 'spider'}
# {'id': 4756, 'pet_name': 'spider'}
# {'id': 4766, 'pet_name': 'spider'}
# {'id': 4771, 'pet_name': 'spider'}
# {'id': 4781, 'pet_name': 'spider'}
# {'id': 4790, 'pet_name': 'spider'}
# {'id': 4792, 'pet_name': 'spider'}
# {'id': 4793, 'pet_name': 'spider'}
# {'id': 4809, 'pet_name': 'spider'}
# {'id': 4811, 'pet_name': 'spider'}
# {'id': 4813, 'pet_name': 'spider'}
# {'id': 4825, 'pet_name': 'spider'}
# {'id': 4830, 'pet_name': 'spider'}
# {'id': 4839, 'pet_name': 'spider'}
# {'id': 4851, 'pet_name': 'spider'}
# {'id': 4852, 'pet_name': 'spider'}
# {'id': 4859, 'pet_name': 'spider'}
# {'id': 4864, 'pet_name': 'spider'}
# {'id': 4865, 'pet_name': 'spider'}
# {'id': 4868, 'pet_name': 'spider'}
# {'id': 4869, 'pet_name': 'spider'}
# {'id': 4870, 'pet_name': 'spider'}
# {'id': 4873, 'pet_name': 'spider'}
# {'id': 4886, 'pet_name': 'spider'}
# {'id': 4895, 'pet_name': 'spider'}
# {'id': 4913, 'pet_name': 'spider'}
# {'id': 4917, 'pet_name': 'spider'}
# {'id': 4920, 'pet_name': 'spider'}
# {'id': 4921, 'pet_name': 'spider'}
# {'id': 4925, 'pet_name': 'spider'}
# {'id': 4928, 'pet_name': 'spider'}
# {'id': 4947, 'pet_name': 'spider'}
# {'id': 4949, 'pet_name': 'spider'}
# {'id': 4955, 'pet_name': 'spider'}
# {'id': 4981, 'pet_name': 'spider'}
# {'id': 4991, 'pet_name': 'spider'}
# {'id': 5000, 'pet_name': 'spider'}
# {'id': 5003, 'pet_name': 'spider'}
# {'id': 5017, 'pet_name': 'spider'}
# {'id': 5022, 'pet_name': 'spider'}
# {'id': 5037, 'pet_name': 'spider'}
# {'id': 5049, 'pet_name': 'spider'}
# {'id': 5050, 'pet_name': 'spider'}
# {'id': 5058, 'pet_name': 'spider'}
# {'id': 5062, 'pet_name': 'spider'}
# {'id': 5064, 'pet_name': 'spider'}
# {'id': 5073, 'pet_name': 'spider'}
# {'id': 5078, 'pet_name': 'spider'}
# {'id': 5085, 'pet_name': 'spider'}
# {'id': 5093, 'pet_name': 'spider'}
# {'id': 5098, 'pet_name': 'spider'}
# {'id': 5105, 'pet_name': 'spider'}
# {'id': 5111, 'pet_name': 'spider'}
# {'id': 5116, 'pet_name': 'spider'}
# {'id': 5122, 'pet_name': 'spider'}
# {'id': 5131, 'pet_name': 'spider'}
# {'id': 5133, 'pet_name': 'spider'}
# {'id': 5150, 'pet_name': 'spider'}
# {'id': 5160, 'pet_name': 'spider'}
# {'id': 5164, 'pet_name': 'spider'}
# {'id': 5171, 'pet_name': 'spider'}
# {'id': 5185, 'pet_name': 'spider'}
# {'id': 5192, 'pet_name': 'spider'}
# {'id': 5195, 'pet_name': 'spider'}
# {'id': 5210, 'pet_name': 'spider'}
# {'id': 5225, 'pet_name': 'spider'}
# {'id': 5231, 'pet_name': 'spider'}
# {'id': 5239, 'pet_name': 'spider'}
# {'id': 5251, 'pet_name': 'spider'}
# {'id': 5253, 'pet_name': 'spider'}
# {'id': 5255, 'pet_name': 'spider'}
# {'id': 5256, 'pet_name': 'spider'}
# {'id': 5259, 'pet_name': 'spider'}
# {'id': 5269, 'pet_name': 'spider'}
# {'id': 5310, 'pet_name': 'spider'}
# {'id': 5317, 'pet_name': 'spider'}
# {'id': 5327, 'pet_name': 'spider'}
# {'id': 5330, 'pet_name': 'spider'}
# {'id': 5362, 'pet_name': 'spider'}
# {'id': 5374, 'pet_name': 'spider'}
# {'id': 5378, 'pet_name': 'spider'}
# {'id': 5379, 'pet_name': 'spider'}
# {'id': 5386, 'pet_name': 'spider'}
# {'id': 5389, 'pet_name': 'spider'}
# {'id': 5392, 'pet_name': 'spider'}
# {'id': 5419, 'pet_name': 'spider'}
# {'id': 5428, 'pet_name': 'spider'}
# {'id': 5436, 'pet_name': 'spider'}
# {'id': 5440, 'pet_name': 'spider'}
# {'id': 5444, 'pet_name': 'spider'}
# {'id': 5452, 'pet_name': 'spider'}
# {'id': 5457, 'pet_name': 'spider'}
# {'id': 5459, 'pet_name': 'spider'}
# {'id': 5461, 'pet_name': 'spider'}
# {'id': 5464, 'pet_name': 'spider'}
# {'id': 5473, 'pet_name': 'spider'}
# {'id': 5482, 'pet_name': 'spider'}
# {'id': 5483, 'pet_name': 'spider'}
# {'id': 5485, 'pet_name': 'spider'}
# {'id': 5505, 'pet_name': 'spider'}
# {'id': 5511, 'pet_name': 'spider'}
# {'id': 5515, 'pet_name': 'spider'}
# {'id': 5524, 'pet_name': 'spider'}
# {'id': 5526, 'pet_name': 'spider'}
# {'id': 5541, 'pet_name': 'spider'}
# {'id': 5543, 'pet_name': 'spider'}
# {'id': 5561, 'pet_name': 'spider'}
# {'id': 5578, 'pet_name': 'spider'}
# {'id': 5580, 'pet_name': 'spider'}
# {'id': 5588, 'pet_name': 'spider'}
# {'id': 5591, 'pet_name': 'spider'}
# {'id': 5592, 'pet_name': 'spider'}
# {'id': 5600, 'pet_name': 'spider'}
# {'id': 5604, 'pet_name': 'spider'}
# {'id': 5610, 'pet_name': 'spider'}
# {'id': 5620, 'pet_name': 'spider'}
# {'id': 5629, 'pet_name': 'spider'}
# {'id': 5630, 'pet_name': 'spider'}
# {'id': 5633, 'pet_name': 'spider'}
# {'id': 5637, 'pet_name': 'spider'}
# {'id': 5660, 'pet_name': 'spider'}
# {'id': 5667, 'pet_name': 'spider'}
# {'id': 5671, 'pet_name': 'spider'}
# {'id': 5683, 'pet_name': 'spider'}
# {'id': 5696, 'pet_name': 'spider'}
# {'id': 5704, 'pet_name': 'spider'}
# {'id': 5719, 'pet_name': 'spider'}
# {'id': 5743, 'pet_name': 'spider'}
# {'id': 5750, 'pet_name': 'spider'}
# {'id': 5755, 'pet_name': 'spider'}
# {'id': 5767, 'pet_name': 'spider'}
# {'id': 5768, 'pet_name': 'spider'}
# {'id': 5776, 'pet_name': 'spider'}
# {'id': 5787, 'pet_name': 'spider'}
# {'id': 5821, 'pet_name': 'spider'}
# {'id': 5823, 'pet_name': 'spider'}
# {'id': 5824, 'pet_name': 'spider'}
# {'id': 5826, 'pet_name': 'spider'}
# {'id': 5837, 'pet_name': 'spider'}
# {'id': 5855, 'pet_name': 'spider'}
# {'id': 5879, 'pet_name': 'spider'}
# {'id': 5887, 'pet_name': 'spider'}
# {'id': 5928, 'pet_name': 'spider'}
# {'id': 5974, 'pet_name': 'spider'}
# {'id': 5976, 'pet_name': 'spider'}
# {'id': 5980, 'pet_name': 'spider'}
# {'id': 5987, 'pet_name': 'spider'}
# {'id': 5989, 'pet_name': 'spider'}
# {'id': 6007, 'pet_name': 'spider'}
# {'id': 6020, 'pet_name': 'spider'}
# {'id': 6043, 'pet_name': 'spider'}
# {'id': 6081, 'pet_name': 'spider'}
# {'id': 6100, 'pet_name': 'spider'}
# {'id': 6104, 'pet_name': 'spider'}
# {'id': 6112, 'pet_name': 'spider'}
# {'id': 6113, 'pet_name': 'spider'}
# {'id': 6131, 'pet_name': 'spider'}
# {'id': 6170, 'pet_name': 'spider'}
# {'id': 6172, 'pet_name': 'spider'}
# {'id': 6185, 'pet_name': 'spider'}
# {'id': 6192, 'pet_name': 'spider'}
# {'id': 6210, 'pet_name': 'spider'}
# {'id': 6216, 'pet_name': 'spider'}
# {'id': 6249, 'pet_name': 'spider'}
# {'id': 6255, 'pet_name': 'spider'}
# {'id': 6265, 'pet_name': 'spider'}
# {'id': 6270, 'pet_name': 'spider'}
# {'id': 6274, 'pet_name': 'spider'}
# {'id': 6286, 'pet_name': 'spider'}
# {'id': 6297, 'pet_name': 'spider'}
# {'id': 6306, 'pet_name': 'spider'}
# {'id': 6316, 'pet_name': 'spider'}
# {'id': 6332, 'pet_name': 'spider'}
# {'id': 6337, 'pet_name': 'spider'}
# {'id': 6343, 'pet_name': 'spider'}
# {'id': 6344, 'pet_name': 'spider'}
# {'id': 6346, 'pet_name': 'spider'}
# {'id': 6350, 'pet_name': 'spider'}
# {'id': 6352, 'pet_name': 'spider'}
# {'id': 6380, 'pet_name': 'spider'}
# {'id': 6392, 'pet_name': 'spider'}
# {'id': 6394, 'pet_name': 'spider'}
# {'id': 6438, 'pet_name': 'spider'}
# {'id': 6440, 'pet_name': 'spider'}
# {'id': 6443, 'pet_name': 'spider'}
# {'id': 6445, 'pet_name': 'spider'}
# {'id': 6446, 'pet_name': 'spider'}
# {'id': 6448, 'pet_name': 'spider'}
# {'id': 6455, 'pet_name': 'spider'}
# {'id': 6456, 'pet_name': 'spider'}
# {'id': 6469, 'pet_name': 'spider'}
# {'id': 6504, 'pet_name': 'spider'}
# {'id': 6506, 'pet_name': 'spider'}
# {'id': 6511, 'pet_name': 'spider'}
# {'id': 6516, 'pet_name': 'spider'}
# {'id': 6525, 'pet_name': 'spider'}
# {'id': 6530, 'pet_name': 'spider'}
# {'id': 6534, 'pet_name': 'spider'}
# {'id': 6536, 'pet_name': 'spider'}
# {'id': 6542, 'pet_name': 'spider'}
# {'id': 6550, 'pet_name': 'spider'}
# {'id': 6564, 'pet_name': 'spider'}
# {'id': 6575, 'pet_name': 'spider'}
# {'id': 6593, 'pet_name': 'spider'}
# {'id': 6607, 'pet_name': 'spider'}
# {'id': 6609, 'pet_name': 'spider'}
# {'id': 6618, 'pet_name': 'spider'}
# {'id': 6619, 'pet_name': 'spider'}
# {'id': 6625, 'pet_name': 'spider'}
# {'id': 6632, 'pet_name': 'spider'}
# {'id': 6642, 'pet_name': 'spider'}
# {'id': 6644, 'pet_name': 'spider'}
# {'id': 6666, 'pet_name': 'spider'}
# {'id': 6675, 'pet_name': 'spider'}
# {'id': 6686, 'pet_name': 'spider'}
# {'id': 6746, 'pet_name': 'spider'}
# {'id': 6751, 'pet_name': 'spider'}
# {'id': 6770, 'pet_name': 'spider'}
# {'id': 6809, 'pet_name': 'spider'}
# {'id': 6810, 'pet_name': 'spider'}
# {'id': 6819, 'pet_name': 'spider'}
# {'id': 6837, 'pet_name': 'spider'}
# {'id': 6839, 'pet_name': 'spider'}
# {'id': 6841, 'pet_name': 'spider'}
# {'id': 6844, 'pet_name': 'spider'}
# {'id': 6855, 'pet_name': 'spider'}
# {'id': 6866, 'pet_name': 'spider'}
# {'id': 6884, 'pet_name': 'spider'}
# {'id': 6888, 'pet_name': 'spider'}
# {'id': 6900, 'pet_name': 'spider'}
# {'id': 6906, 'pet_name': 'spider'}
# {'id': 6937, 'pet_name': 'spider'}
# {'id': 6971, 'pet_name': 'spider'}
# {'id': 6974, 'pet_name': 'spider'}
# {'id': 6978, 'pet_name': 'spider'}
# {'id': 6979, 'pet_name': 'spider'}
# {'id': 6989, 'pet_name': 'spider'}
# {'id': 6992, 'pet_name': 'spider'}
# {'id': 6997, 'pet_name': 'spider'}
# {'id': 7016, 'pet_name': 'spider'}
# {'id': 7017, 'pet_name': 'spider'}
# {'id': 7020, 'pet_name': 'spider'}
# {'id': 7026, 'pet_name': 'spider'}
# {'id': 7033, 'pet_name': 'spider'}
# {'id': 7076, 'pet_name': 'spider'}
# {'id': 7082, 'pet_name': 'spider'}
# {'id': 7083, 'pet_name': 'spider'}
# {'id': 7113, 'pet_name': 'spider'}
# {'id': 7120, 'pet_name': 'spider'}
# {'id': 7122, 'pet_name': 'spider'}
# {'id': 7131, 'pet_name': 'spider'}
# {'id': 7156, 'pet_name': 'spider'}
# {'id': 7158, 'pet_name': 'spider'}
# {'id': 7216, 'pet_name': 'spider'}
# {'id': 7254, 'pet_name': 'spider'}
# {'id': 7263, 'pet_name': 'spider'}
# {'id': 7281, 'pet_name': 'spider'}
# {'id': 7283, 'pet_name': 'spider'}
# {'id': 7288, 'pet_name': 'spider'}
# {'id': 7297, 'pet_name': 'spider'}
# {'id': 7306, 'pet_name': 'spider'}
# {'id': 7308, 'pet_name': 'spider'}
# {'id': 7310, 'pet_name': 'spider'}
# {'id': 7313, 'pet_name': 'spider'}
# {'id': 7350, 'pet_name': 'spider'}
# {'id': 7359, 'pet_name': 'spider'}
# {'id': 7398, 'pet_name': 'spider'}
# {'id': 7400, 'pet_name': 'spider'}
# {'id': 7403, 'pet_name': 'spider'}
# {'id': 7409, 'pet_name': 'spider'}
# {'id': 7414, 'pet_name': 'spider'}
# {'id': 7423, 'pet_name': 'spider'}
# {'id': 7439, 'pet_name': 'spider'}
# {'id': 7448, 'pet_name': 'spider'}
# {'id': 7465, 'pet_name': 'spider'}
# {'id': 7471, 'pet_name': 'spider'}
# {'id': 7481, 'pet_name': 'spider'}
# {'id': 7483, 'pet_name': 'spider'}
# {'id': 7486, 'pet_name': 'spider'}
# {'id': 7494, 'pet_name': 'spider'}
# {'id': 7502, 'pet_name': 'spider'}
# {'id': 7506, 'pet_name': 'spider'}
# {'id': 7521, 'pet_name': 'spider'}
# {'id': 7525, 'pet_name': 'spider'}
# {'id': 7538, 'pet_name': 'spider'}
# {'id': 7546, 'pet_name': 'spider'}
# {'id': 7553, 'pet_name': 'spider'}
# {'id': 7568, 'pet_name': 'spider'}
# {'id': 7577, 'pet_name': 'spider'}
# {'id': 7586, 'pet_name': 'spider'}
# {'id': 7589, 'pet_name': 'spider'}
# {'id': 7593, 'pet_name': 'spider'}
# {'id': 7597, 'pet_name': 'spider'}
# {'id': 7601, 'pet_name': 'spider'}
# {'id': 7618, 'pet_name': 'spider'}
# {'id': 7640, 'pet_name': 'spider'}
# {'id': 7660, 'pet_name': 'spider'}
# {'id': 7665, 'pet_name': 'spider'}
# {'id': 7673, 'pet_name': 'spider'}
# {'id': 7685, 'pet_name': 'spider'}
# {'id': 7707, 'pet_name': 'spider'}
# {'id': 7712, 'pet_name': 'spider'}
# {'id': 7714, 'pet_name': 'spider'}
# {'id': 7732, 'pet_name': 'spider'}
# {'id': 7740, 'pet_name': 'spider'}
# {'id': 7750, 'pet_name': 'spider'}
# {'id': 7752, 'pet_name': 'spider'}
# {'id': 7761, 'pet_name': 'spider'}
# {'id': 7787, 'pet_name': 'spider'}
# {'id': 7788, 'pet_name': 'spider'}
# {'id': 7798, 'pet_name': 'spider'}
# {'id': 7800, 'pet_name': 'spider'}
# {'id': 7815, 'pet_name': 'spider'}
# {'id': 7821, 'pet_name': 'spider'}
# {'id': 7823, 'pet_name': 'spider'}
# {'id': 7826, 'pet_name': 'spider'}
# {'id': 7830, 'pet_name': 'spider'}
# {'id': 7838, 'pet_name': 'spider'}
# {'id': 7840, 'pet_name': 'spider'}
# {'id': 7876, 'pet_name': 'spider'}
# {'id': 7877, 'pet_name': 'spider'}
# {'id': 7890, 'pet_name': 'spider'}
# {'id': 7901, 'pet_name': 'spider'}
# {'id': 7903, 'pet_name': 'spider'}
# {'id': 7906, 'pet_name': 'spider'}
# {'id': 7920, 'pet_name': 'spider'}
# {'id': 7922, 'pet_name': 'spider'}
# {'id': 7931, 'pet_name': 'spider'}
# {'id': 7953, 'pet_name': 'spider'}
# {'id': 7988, 'pet_name': 'spider'}
# {'id': 7999, 'pet_name': 'spider'}
# {'id': 8027, 'pet_name': 'spider'}
# {'id': 8031, 'pet_name': 'spider'}
# {'id': 8051, 'pet_name': 'spider'}
# {'id': 8057, 'pet_name': 'spider'}
# {'id': 8069, 'pet_name': 'spider'}
# {'id': 8071, 'pet_name': 'spider'}
# {'id': 8072, 'pet_name': 'spider'}
# {'id': 8073, 'pet_name': 'spider'}
# {'id': 8074, 'pet_name': 'spider'}
# {'id': 8077, 'pet_name': 'spider'}
# {'id': 8089, 'pet_name': 'spider'}
# {'id': 8102, 'pet_name': 'spider'}
# {'id': 8109, 'pet_name': 'spider'}
# {'id': 8112, 'pet_name': 'spider'}
# {'id': 8116, 'pet_name': 'spider'}
# {'id': 8124, 'pet_name': 'spider'}
# {'id': 8138, 'pet_name': 'spider'}
# {'id': 8139, 'pet_name': 'spider'}
# {'id': 8157, 'pet_name': 'spider'}
# {'id': 8166, 'pet_name': 'spider'}
# {'id': 8169, 'pet_name': 'spider'}
# {'id': 8174, 'pet_name': 'spider'}
# {'id': 8186, 'pet_name': 'spider'}
# {'id': 8197, 'pet_name': 'spider'}
# {'id': 8202, 'pet_name': 'spider'}
# {'id': 8207, 'pet_name': 'spider'}
# {'id': 8213, 'pet_name': 'spider'}
# {'id': 8219, 'pet_name': 'spider'}
# {'id': 8223, 'pet_name': 'spider'}
# {'id': 8230, 'pet_name': 'spider'}
# {'id': 8244, 'pet_name': 'spider'}
# {'id': 8254, 'pet_name': 'spider'}
# {'id': 8257, 'pet_name': 'spider'}
# {'id': 8301, 'pet_name': 'spider'}
# {'id': 8307, 'pet_name': 'spider'}
# {'id': 8309, 'pet_name': 'spider'}
# {'id': 8310, 'pet_name': 'spider'}
# {'id': 8315, 'pet_name': 'spider'}
# {'id': 8316, 'pet_name': 'spider'}
# {'id': 8333, 'pet_name': 'spider'}
# {'id': 8349, 'pet_name': 'spider'}
# {'id': 8353, 'pet_name': 'spider'}
# {'id': 8363, 'pet_name': 'spider'}
# {'id': 8392, 'pet_name': 'spider'}
# {'id': 8418, 'pet_name': 'spider'}
# {'id': 8436, 'pet_name': 'spider'}
# {'id': 8439, 'pet_name': 'spider'}
# {'id': 8467, 'pet_name': 'spider'}
# {'id': 8475, 'pet_name': 'spider'}
# {'id': 8476, 'pet_name': 'spider'}
# {'id': 8479, 'pet_name': 'spider'}
# {'id': 8497, 'pet_name': 'spider'}
# {'id': 8500, 'pet_name': 'spider'}
# {'id': 8502, 'pet_name': 'spider'}
# {'id': 8523, 'pet_name': 'spider'}
# {'id': 8544, 'pet_name': 'spider'}
# {'id': 8557, 'pet_name': 'spider'}
# {'id': 8574, 'pet_name': 'spider'}
# {'id': 8580, 'pet_name': 'spider'}
# {'id': 8586, 'pet_name': 'spider'}
# {'id': 8588, 'pet_name': 'spider'}
# {'id': 8589, 'pet_name': 'spider'}
# {'id': 8597, 'pet_name': 'spider'}
# {'id': 8602, 'pet_name': 'spider'}
# {'id': 8614, 'pet_name': 'spider'}
# {'id': 8619, 'pet_name': 'spider'}
# {'id': 8628, 'pet_name': 'spider'}
# {'id': 8642, 'pet_name': 'spider'}
# {'id': 8661, 'pet_name': 'spider'}
# {'id': 8665, 'pet_name': 'spider'}
# {'id': 8673, 'pet_name': 'spider'}
# {'id': 8689, 'pet_name': 'spider'}
# {'id': 8690, 'pet_name': 'spider'}
# {'id': 8708, 'pet_name': 'spider'}
# {'id': 8738, 'pet_name': 'spider'}
# {'id': 8748, 'pet_name': 'spider'}
# {'id': 8754, 'pet_name': 'spider'}
# {'id': 8760, 'pet_name': 'spider'}
# {'id': 8765, 'pet_name': 'spider'}
# {'id': 8779, 'pet_name': 'spider'}
# {'id': 8810, 'pet_name': 'spider'}
# {'id': 8812, 'pet_name': 'spider'}
# {'id': 8814, 'pet_name': 'spider'}
# {'id': 8837, 'pet_name': 'spider'}
# {'id': 8844, 'pet_name': 'spider'}
# {'id': 8869, 'pet_name': 'spider'}
# {'id': 8878, 'pet_name': 'spider'}
# {'id': 8886, 'pet_name': 'spider'}
# {'id': 8899, 'pet_name': 'spider'}
# {'id': 8930, 'pet_name': 'spider'}
# {'id': 8953, 'pet_name': 'spider'}
# {'id': 8957, 'pet_name': 'spider'}
# {'id': 8971, 'pet_name': 'spider'}
# {'id': 8974, 'pet_name': 'spider'}
# {'id': 8980, 'pet_name': 'spider'}
# {'id': 8983, 'pet_name': 'spider'}
# {'id': 9003, 'pet_name': 'spider'}
# {'id': 9015, 'pet_name': 'spider'}
# {'id': 9024, 'pet_name': 'spider'}
# {'id': 9032, 'pet_name': 'spider'}
# {'id': 9042, 'pet_name': 'spider'}
# {'id': 9043, 'pet_name': 'spider'}
# {'id': 9056, 'pet_name': 'spider'}
# {'id': 9057, 'pet_name': 'spider'}
# {'id': 9058, 'pet_name': 'spider'}
# {'id': 9061, 'pet_name': 'spider'}
# {'id': 9075, 'pet_name': 'spider'}
# {'id': 9106, 'pet_name': 'spider'}
# {'id': 9122, 'pet_name': 'spider'}
# {'id': 9123, 'pet_name': 'spider'}
# {'id': 9133, 'pet_name': 'spider'}
# {'id': 9139, 'pet_name': 'spider'}
# {'id': 9142, 'pet_name': 'spider'}
# {'id': 9163, 'pet_name': 'spider'}
# {'id': 9190, 'pet_name': 'spider'}
# {'id': 9191, 'pet_name': 'spider'}
# {'id': 9194, 'pet_name': 'spider'}
# {'id': 9241, 'pet_name': 'spider'}
# {'id': 9242, 'pet_name': 'spider'}
# {'id': 9255, 'pet_name': 'spider'}
# {'id': 9257, 'pet_name': 'spider'}
# {'id': 9287, 'pet_name': 'spider'}
# {'id': 9288, 'pet_name': 'spider'}
# {'id': 9289, 'pet_name': 'spider'}
# {'id': 9294, 'pet_name': 'spider'}
# {'id': 9299, 'pet_name': 'spider'}
# {'id': 9301, 'pet_name': 'spider'}
# {'id': 9306, 'pet_name': 'spider'}
# {'id': 9314, 'pet_name': 'spider'}
# {'id': 9315, 'pet_name': 'spider'}
# {'id': 9318, 'pet_name': 'spider'}
# {'id': 9322, 'pet_name': 'spider'}
# {'id': 9332, 'pet_name': 'spider'}
# {'id': 9346, 'pet_name': 'spider'}
# {'id': 9353, 'pet_name': 'spider'}
# {'id': 9356, 'pet_name': 'spider'}
# {'id': 9364, 'pet_name': 'spider'}
# {'id': 9376, 'pet_name': 'spider'}
# {'id': 9401, 'pet_name': 'spider'}
# {'id': 9409, 'pet_name': 'spider'}
# {'id': 9467, 'pet_name': 'spider'}
# {'id': 9470, 'pet_name': 'spider'}
# {'id': 9479, 'pet_name': 'spider'}
# {'id': 9480, 'pet_name': 'spider'}
# {'id': 9484, 'pet_name': 'spider'}
# {'id': 9490, 'pet_name': 'spider'}
# {'id': 9491, 'pet_name': 'spider'}
# {'id': 9494, 'pet_name': 'spider'}
# {'id': 9495, 'pet_name': 'spider'}
# {'id': 9501, 'pet_name': 'spider'}
# {'id': 9534, 'pet_name': 'spider'}
# {'id': 9539, 'pet_name': 'spider'}
# {'id': 9540, 'pet_name': 'spider'}
# {'id': 9557, 'pet_name': 'spider'}
# {'id': 9581, 'pet_name': 'spider'}
# {'id': 9585, 'pet_name': 'spider'}
# {'id': 9603, 'pet_name': 'spider'}
# {'id': 9611, 'pet_name': 'spider'}
# {'id': 9618, 'pet_name': 'spider'}
# {'id': 9633, 'pet_name': 'spider'}
# {'id': 9642, 'pet_name': 'spider'}
# {'id': 9647, 'pet_name': 'spider'}
# {'id': 9652, 'pet_name': 'spider'}
# {'id': 9663, 'pet_name': 'spider'}
# {'id': 9664, 'pet_name': 'spider'}
# {'id': 9668, 'pet_name': 'spider'}
# {'id': 9673, 'pet_name': 'spider'}
# {'id': 9680, 'pet_name': 'spider'}
# {'id': 9695, 'pet_name': 'spider'}
# {'id': 9700, 'pet_name': 'spider'}
# {'id': 9703, 'pet_name': 'spider'}
# {'id': 9709, 'pet_name': 'spider'}
# {'id': 9715, 'pet_name': 'spider'}
# {'id': 9726, 'pet_name': 'spider'}
# {'id': 9731, 'pet_name': 'spider'}
# {'id': 9751, 'pet_name': 'spider'}
# {'id': 9795, 'pet_name': 'spider'}
# {'id': 9807, 'pet_name': 'spider'}
# {'id': 9811, 'pet_name': 'spider'}
# {'id': 9812, 'pet_name': 'spider'}
# {'id': 9823, 'pet_name': 'spider'}
# {'id': 9842, 'pet_name': 'spider'}
# {'id': 9858, 'pet_name': 'spider'}
# {'id': 9859, 'pet_name': 'spider'}
# {'id': 9865, 'pet_name': 'spider'}
# {'id': 9878, 'pet_name': 'spider'}
# {'id': 9904, 'pet_name': 'spider'}
# {'id': 9905, 'pet_name': 'spider'}
# {'id': 9906, 'pet_name': 'spider'}
# {'id': 9917, 'pet_name': 'spider'}
# {'id': 9926, 'pet_name': 'spider'}
# {'id': 9945, 'pet_name': 'spider'}
# {'id': 9947, 'pet_name': 'spider'}
# {'id': 9956, 'pet_name': 'spider'}
# {'id': 9957, 'pet_name': 'spider'}
# {'id': 9958, 'pet_name': 'spider'}
# {'id': 9966, 'pet_name': 'spider'}
# {'id': 9982, 'pet_name': 'spider'}
# {'id': 9991, 'pet_name': 'spider'}
# {'id': 9994, 'pet_name': 'spider'}
# {'id': 9999, 'pet_name': 'spider'}

# %%
# Compute the ratio of artic pets and savannah pets (based on the arrays created to fill the collections) compared to the number of pets in the collection
savannah_result = client.query(
    collection_name = "zoo_collection",
    filter = 'pet_name in ["lion", "zebra", "snake"]',
    output_fields = ["count(*)"],
)

artic_result = client.query(
    collection_name = "zoo_collection",
    filter = 'pet_name in ["penguin", "whale", "sea lion"]',
    output_fields = ["count(*)"],
)

all_result = client.query(
    collection_name = "zoo_collection",
    output_fields = ["count(*)"],
)


print(str(round(savannah_result[0]["count(*)"]/all_result[0]["count(*)"], 4) * 100) + "%")
print(str(round(artic_result[0]["count(*)"]/all_result[0]["count(*)"], 4) * 100) + "%")
# Out:
# 42.95%
# 39.22%

# %%
# Count the number of entities whose pet_name is penguin or lion
advanced_operator_result = client.query(
    collection_name = "zoo_collection",
    filter = 'pet_name == "penguin" or pet_name == "lion"',
    output_fields = ["count(*)"],
)

print_results(advanced_operator_result)
# Out:
# {'count(*)': 7972}

# %%
# Drop the collection and alias
client.drop_collection(
  collection_name="pet_collection"
)

client.drop_alias(
    collection_name = "pet_collection",
    alias = "zoo_collection"
)

# %%
# Create a new collection with a json field "pet_features" with the species and pet_name fields and an array of randomly generated ages
# Also, remove breeding_vector

# Create a schema
schema = MilvusClient.create_schema(
    auto_id = False,
    enable_dynamic_field = True,
)

schema.add_field(field_name = "id", datatype = DataType.INT64, is_primary = True)
schema.add_field(field_name = "pet_vector", datatype = DataType.FLOAT_VECTOR, dim = 5)
schema.add_field(field_name = "ages", datatype = DataType.ARRAY, element_type = DataType.INT64, max_capacity = 10)
schema.add_field(field_name = "pet_features", datatype = DataType.JSON)

# Add index to id, pet_vector, breed_vector, and species
index_params = client.prepare_index_params()

index_params.add_index(
    field_name = "id",
    index_type = "STL_SORT"
)

index_params.add_index(
    field_name = "pet_vector",
    index_type = "AUTOINDEX",
    metric_type = "IP",
    params = { "nlist": 128 }
)

# Create a collection with the index
client.create_collection(
    collection_name = "pet_collection",
    schema = schema,
    index_params = index_params
)

# Get the collection load state
load_state = client.get_load_state(
    collection_name = "pet_collection"
)

print(load_state)
# Out:
# {'state': <LoadState: Loaded>}

# %%
# Create 10k data for the main collection, using proper animal names based on the biome
import random

# List 10 pets to be inserted in the DB
pet_names = ["cat", "dog", "penguin", "lion", "zebra", "cow", "jaguar", "whale", "snake", "spider"]
# List three random species
species = ["feline", "canine", "insect"]

data = []

# Generate 10'000 animals
for i in range(10000):
    data.append({
        "id": i,
        "pet_vector": [ random.uniform(-1, 1) for _ in range(5) ],
        "ages": [ (j+i) for j in range(10) ],
        "pet_features": {
            "pet_name": random.choice(pet_names),
            "species": random.choice(species)
        }
    })

# %%
# Add data to the collection and return the number of loaded elements
insert_result = client.insert(
    collection_name = "pet_collection",
    data = data,
)

print(insert_result["insert_count"])
# Out:
# 10000

# %%
# Look for all the pets whose name is penguin, cat, or dog and return their pet name that are close to a random pet_vector
pet_vector = [ random.uniform(-1, 1) for _ in range(5) ]

advanced_search_result = client.query(
    collection_name = "pet_collection",
    data = [pet_vector],
    filter = 'pet_features["pet_name"] == "penguin" or pet_features["pet_name"] == "cat" or pet_features["pet_name"] == "dog"',
    output_fields = ["pet_name"],
)

print(advanced_search_result)
# Out:
# data: ["{'id': 2}", "{'id': 9}", "{'id': 19}", "{'id': 22}", "{'id': 26}", "{'id': 37}", "{'id': 39}", "{'id': 43}", "{'id': 45}", "{'id': 47}"] ..., extra_info: {'cost': 6}

# %%
# Look for all the pets whose ages array contains the numbers 11 and 12
advanced_search_result = client.query(
    collection_name = "pet_collection",
    filter = "ARRAY_CONTAINS_ALL(ages, [11, 12])",
    output_fields = ["id"],
    limit = 3
)

print_results(advanced_search_result)
# Out:
# {'id': 3}
# {'id': 4}
# {'id': 5}

# %%
# Drop collection
client.drop_collection(
    collection_name = "pet_collection",
)

# %%
client.drop_alias(
    alias = "zoo_collection"
)
